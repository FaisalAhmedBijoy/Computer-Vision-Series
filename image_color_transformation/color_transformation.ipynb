# %% [markdown]
# ## Import the library

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# input the image
image=cv2.imread('images/faisal.jpg')
image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
print('image shape: ',image.shape)
plt.imshow(image)
# Out:
# image shape:  (960, 960, 3)

# %% [markdown]
# ## Resize the image into a fixed size: 300x300 pixel

# %%
HEIGHT=300
WIDTH=300
resized_image=cv2.resize(image,(HEIGHT,WIDTH))
print('after resize the image shape: ',resized_image.shape)
plt.imshow(resized_image)
# Out:
# after resize the image shape:  (300, 300, 3)

# %% [markdown]
# ## 1. Convert Color RGB to GRAY

# %%
gray_image=cv2.cvtColor(resized_image,cv2.COLOR_RGB2GRAY)
print('gray image shape: ',gray_image.shape)
plt.imshow(gray_image,cmap='gray')
# Out:
# gray image shape:  (300, 300)

# %% [markdown]
# ## 2. Convert color RGB to CIE XYZ

# %%
cie_xyz_image=cv2.cvtColor(resized_image,cv2.COLOR_RGB2XYZ)
print('cie xyz image shape: ',cie_xyz_image.shape)
plt.imshow(cie_xyz_image)
# Out:
# cie xyz image shape:  (300, 300, 3)

# %% [markdown]
# ## 3. Convert color RGB to YCrCb

# %%
ycrcb_image=cv2.cvtColor(resized_image,cv2.COLOR_RGB2YCrCb)
plt.xticks([])
plt.yticks([])
plt.imshow(ycrcb_image)

# %% [markdown]
# ## 4. Conver color RGB to HSV

# %%
hsv_image=cv2.cvtColor(resized_image, cv2.COLOR_RGB2HSV)
plt.xticks([])
plt.yticks([])
plt.imshow(hsv_image)

# %% [markdown]
# ## 5. Convert color RGB to HLS

# %%
hls_image=cv2.cvtColor(resized_image,cv2.COLOR_RGB2HLS)
plt.xticks([])
plt.yticks([])
plt.imshow(hls_image)

# %% [markdown]
# ## 6. Convert color RGB to CIE L* a* b*

# %%
cie_lab_image=cv2.cvtColor(resized_image,cv2.COLOR_RGB2LAB)
plt.xticks([])
plt.yticks([])
plt.imshow(cie_lab_image)

# %% [markdown]
# ## 7. Convert color RGB to CIE L* u* v*

# %%
cie_luv_image=cv2.cvtColor(resized_image,cv2.COLOR_RGB2LUV)
plt.xticks([])
plt.yticks([])
plt.imshow(cie_luv_image)

# %% [markdown]
# ## Show all the image by opencv function

# %%
cv2.imshow('image',image)
cv2.imshow('0. resized image',resized_image)
cv2.imshow('1. gray image',gray_image)
cv2.imshow('2. cie xyz image',cie_xyz_image)
cv2.imshow('3. ycrcb image',ycrcb_image)
cv2.imshow('4. hsv image',hsv_image)
cv2.imshow('5. hls image',hls_image)
cv2.imshow('6. cie lab image',cie_lab_image)
cv2.imshow('7. cie luv image',cie_luv_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
